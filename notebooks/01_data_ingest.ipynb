# %%
import pandas as pd
df = pd.read_csv("../data/processed/player_gw_stats.csv")
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv("../data/processed/player_gw_stats.csv")
#
# ...

# %%
import os

# 1. Where is Jupyter actually running?
print("Working dir:", os.getcwd())

# 2. What’s in it?
print("Contents:", os.listdir("."))

# 3. Do we even have a data folder?
print("data in cwd?:", os.path.exists("data"), os.path.isdir("data"))
if os.path.exists("data"):
    print("data contains:", os.listdir("data"))
# Out:
# Working dir: /Users/gabrieltang/Documents/fpl-points-predictor/notebooks
# Contents: ['01_data_ingest.ipynb']
# data in cwd?: False False

# %%
import pandas as pd

# Adjust path if needed:
path = "data/raw/historical/fpl_training.csv"
df = pd.read_csv(path, nrows=5)

print("Columns in historical file:", df.columns.tolist())
print(df.head(3))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 5
#       3 # Adjust path if needed:
#       4 path = "data/raw/historical/fpl_training.csv"
# ----> 5 df = pd.read_csv(path, nrows=5)
#       7 print("Columns in historical file:", df.columns.tolist())
#       8 print(df.head(3))
#
# ...

# %%
import os, pandas as pd

# 1. See where we are
print("Notebook cwd:", os.getcwd())
print("data/raw contains:", os.listdir(os.path.join("..","data","raw")))

# 2. Confirm your historical folder
hist_path = os.path.join("..","data","raw","historical")
print("historical contains:", os.listdir(hist_path))

# 3. Now read with the correct relative path
csv_path = os.path.join(hist_path, "fpl_training.csv")
print("Loading from:", csv_path)
df = pd.read_csv(csv_path, nrows=5)
print("Columns:", df.columns.tolist())
# Out:
# Notebook cwd: /Users/gabrieltang/Documents/fpl-points-predictor/notebooks
# data/raw contains: ['bootstrap_element_stats.csv', 'bootstrap_element_types.csv', 'bootstrap_chips.csv', 'bootstrap_events.csv', 'historical', 'bootstrap_elements.csv', 'history', 'fixtures.csv', 'bootstrap_teams.csv', 'bootstrap_phases.csv']
# historical contains: ['fpl_training.csv']
# Loading from: ../data/raw/historical/fpl_training.csv
# ...

# %%
import pandas as pd

# Adjust path if needed:
path = "../data/raw/historical/fpl_training.csv"
df = pd.read_csv(path, nrows=5)

print("Columns in historical file:", df.columns.tolist())
print(df.head(3))
# Out:
# Columns in historical file: ['element', 'round', 'assists', 'bonus', 'bps', 'clean_sheets', 'value', 'creativity', 'total_points', 'goals_conceded', 'goals_scored', 'ict_index', 'influence', 'minutes', 'opponent_team', 'red_cards', 'saves', 'selected_by_percent', 'threat', 'transfers_balance', 'was_home', 'yellow_cards', 'label', 'player_name', 'web_name', 'element_type', 'player_team', 'understat_id', 'h_team', 'a_team', 'shots', 'xG', 'xA', 'key_passes', 'npg', 'npxG', 'xGChain', 'xGBuildup', 'xG_player_team', 'xGA_player_team', 'npxG_player_team', 'npxGA_player_team', 'deep_player_team', 'deep_allowed_player_team', 'scored_player_team', 'missed_player_team', 'npxGD_player_team', 'ppda_att_player_team', 'ppda_def_player_team', 'ppda_allowed_att_player_team', 'ppda_allowed_def_player_team', 'xG_opponent_team', 'xGA_opponent_team', 'npxG_opponent_team', 'npxGA_opponent_team', 'deep_opponent_team', 'deep_allowed_opponent_team', 'scored_opponent_team', 'missed_opponent_team', 'npxGD_op
# ...

# %%
import sys, os

# Make sure the parent folder (project root) is on sys.path
ROOT = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
if ROOT not in sys.path:
    sys.path.insert(0, ROOT)

print("PYTHONPATH:", sys.path[0])

import pandas as pd
from src.features import load_processed, make_features, get_X_y
from sklearn.model_selection import train_test_split

# 1. Load and featurize exactly as in src/model.py
df   = load_processed("data/processed/player_gw_stats.csv")
feat = make_features(df, window=3)
X, y = get_X_y(feat)

# 2. Time‐aware split (same as model.py)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, shuffle=False
)
# Out:
# PYTHONPATH: /Users/gabrieltang/Documents/fpl-points-predictor
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 15
#      12 from sklearn.model_selection import train_test_split
#      14 # 1. Load and featurize exactly as in src/model.py
# ---> 15 df   = load_processed("data/processed/player_gw_stats.csv")
#      16 feat = make_features(df, window=3)
#      17 X, y = get_X_y(feat)
#
# File ~/Documents/fpl-points-predictor/src/features.py:6, in load_processed(path)
#       4 def load_processed(path: str = "data/processed/player_gw_stats.csv") -> pd.DataFrame:
#       5     """Load your merged GW-level stats into a DataFrame."""
# ----> 6     return pd.read_csv(path)
#
# ...

# %%
import sys, os

# Make sure the parent folder (project root) is on sys.path
ROOT = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
if ROOT not in sys.path:
    sys.path.insert(0, ROOT)

print("PYTHONPATH:", sys.path[0])

import pandas as pd
from src.features import load_processed, make_features, get_X_y
from sklearn.model_selection import train_test_split

# 1. Load and featurize exactly as in src/model.py
df   = load_processed("data/processed/player_gw_stats.csv")
feat = make_features(df, window=3)
X, y = get_X_y(feat)

# 2. Time‐aware split (same as model.py)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, shuffle=False
)
# Out:
# PYTHONPATH: /Users/gabrieltang/Documents/fpl-points-predictor
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 15
#      12 from sklearn.model_selection import train_test_split
#      14 # 1. Load and featurize exactly as in src/model.py
# ---> 15 df   = load_processed("data/processed/player_gw_stats.csv")
#      16 feat = make_features(df, window=3)
#      17 X, y = get_X_y(feat)
#
# File ~/Documents/fpl-points-predictor/src/features.py:6, in load_processed(path)
#       4 def load_processed(path: str = "data/processed/player_gw_stats.csv") -> pd.DataFrame:
#       5     """Load your merged GW-level stats into a DataFrame."""
# ----> 6     return pd.read_csv(path)
#
# ...

# %%
# 0) If not done already, make src/ importable:
import sys, os
ROOT = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
sys.path.insert(0, ROOT)

# 1) Imports
import pandas as pd
from src.features import load_processed, make_features, get_X_y
from sklearn.model_selection import train_test_split
from joblib import load
import matplotlib.pyplot as plt

# 2) Load processed data (note the "../")
df = load_processed("../data/processed/player_gw_stats.csv")

# 3) Feature engineering
feat = make_features(df, window=3)
X, y = get_X_y(feat)

# 4) Train/test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, shuffle=False
)

# 5) Load your model
model = load("../models/baseline.joblib")  # or rf.joblib

# 6) Predict
preds = model.predict(X_test)

# 7) Plot
plt.figure(figsize=(6,6))
plt.scatter(y_test, preds, alpha=0.3)
mn, mx = min(y_test.min(), preds.min()), max(y_test.max(), preds.max())
plt.plot([mn, mx], [mn, mx], "--", color="gray")
plt.xlabel("Actual FPL Points")
plt.ylabel("Predicted FPL Points")
plt.title("Pred vs Actual FPL Points")
plt.show()

# %%
import sys, os
ROOT = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
if ROOT not in sys.path:
    sys.path.insert(0, ROOT)


import sys, os
import pandas as pd
from src.features import load_processed, make_features, get_X_y
from sklearn.model_selection import train_test_split
from joblib import load
import matplotlib.pyplot as plt

# 1) Make sure src/ is importable
ROOT = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
if ROOT not in sys.path:
    sys.path.insert(0, ROOT)

# 2) Load & featurize
df   = load_processed("../data/processed/player_gw_stats.csv")
feat = make_features(df, window=3)
X, y = get_X_y(feat)

# 3) Same train/test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, shuffle=False
)

# 4) Load your model
model = load("../models/baseline.joblib")  # or rf.joblib

# 5) Predict
preds = model.predict(X_test)

# 6a) Zoomed scatter
plt.figure(figsize=(6,6))
plt.scatter(y_test, preds, alpha=0.3)
limit = 20
plt.plot([0,limit],[0,limit],"--", linewidth=1)
plt.xlim(0, limit)
plt.ylim(0, limit)
plt.xlabel("Actual FPL Points")
plt.ylabel("Predicted FPL Points")
plt.title("Zoomed: Pred vs Actual (0–20)")
plt.show()

# 6b) Hexbin density
plt.figure(figsize=(6,6))
hb = plt.hexbin(y_test, preds, gridsize=40)  # no cmap → default colormap
plt.plot([0,limit],[0,limit],"--", linewidth=1)
plt.xlim(0, limit)
plt.ylim(0, limit)
plt.xlabel("Actual FPL Points")
plt.ylabel("Predicted FPL Points")
plt.title("Density (Hexbin) Pred vs Actual (0–20)")
plt.colorbar(label="Count")
plt.show()

# %%
import sys, os
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

import sys, os
import pandas as pd
from src.features import load_processed, make_features, get_X_y
from sklearn.model_selection import train_test_split
from joblib import load
import matplotlib.pyplot as plt

# 1) Make sure src/ is importable
ROOT = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
if ROOT not in sys.path:
    sys.path.insert(0, ROOT)

# 2) Load & featurize
df   = load_processed("../data/processed/player_gw_stats.csv")
feat = make_features(df, window=3)
X, y = get_X_y(feat)

# 3) Same train/test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, shuffle=False
)

# 4) Load your model
model = load("../models/rf_tuned.joblib")  # or rf.joblib

# 5) Predict
preds = model.predict(X_test)

# 6a) Zoomed scatter
plt.figure(figsize=(6,6))
plt.scatter(y_test, preds, alpha=0.3)
limit = 20
plt.plot([0,limit],[0,limit],"--", linewidth=1)
plt.xlim(0, limit)
plt.ylim(0, limit)
plt.xlabel("Actual FPL Points")
plt.ylabel("Predicted FPL Points")
plt.title("Zoomed: Pred vs Actual (0–20)")
plt.show()

# 6b) Hexbin density
plt.figure(figsize=(6,6))
hb = plt.hexbin(y_test, preds, gridsize=40)  # no cmap → default colormap
plt.plot([0,limit],[0,limit],"--", linewidth=1)
plt.xlim(0, limit)
plt.ylim(0, limit)
plt.xlabel("Actual FPL Points")
plt.ylabel("Predicted FPL Points")
plt.title("Density (Hexbin) Pred vs Actual (0–20)")
plt.colorbar(label="Count")
plt.show()

# %%
import sys, os
import pandas as pd
from src.features import load_processed, make_features, get_X_y
from sklearn.model_selection import train_test_split
from joblib import load
import matplotlib.pyplot as plt


# 2) Load & featurize just like in model.py
df   = load_processed("data/processed/player_gw_stats.csv")
feat = make_features(df, window=3)
X, y = get_X_y(feat)

# 3) Train/test split (time‐aware)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, shuffle=False
)

# 4) Load your Random Forest model
model = load("models/rf.joblib")

# 5) Pull out importances
imp = model.feature_importances_
fi = pd.DataFrame({
    "feature": X_train.columns,
    "importance": imp
}).sort_values("importance", ascending=False)

# 6) Bar chart of top 15
top_n = 15
plt.figure(figsize=(6, 4 + top_n*0.2))
plt.barh(fi["feature"].head(top_n)[::-1], fi["importance"].head(top_n)[::-1])
plt.xlabel("Importance")
plt.title("Top 15 Feature Importances (RF)")
plt.tight_layout()
plt.show()

# 7) Show the table
fi.head(top_n).reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[22], line 10
#       6 import matplotlib.pyplot as plt
#       9 # 2) Load & featurize just like in model.py
# ---> 10 df   = load_processed("data/processed/player_gw_stats.csv")
#      11 feat = make_features(df, window=3)
#      12 X, y = get_X_y(feat)
#
# File ~/Documents/fpl-points-predictor/src/features.py:6, in load_processed(path)
#       4 def load_processed(path: str = "data/processed/player_gw_stats.csv") -> pd.DataFrame:
#       5     """Load your merged GW-level stats into a DataFrame."""
# ----> 6     return pd.read_csv(path)
#
# ...

# %%
import sys, os
import pandas as pd
from src.features import load_processed, make_features, get_X_y
from sklearn.model_selection import train_test_split
from joblib import load
import matplotlib.pyplot as plt


# 2) Load & featurize just like in model.py
df   = load_processed("../data/processed/player_gw_stats.csv")
feat = make_features(df, window=3)
X, y = get_X_y(feat)

# 3) Train/test split (time‐aware)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, shuffle=False
)

# 4) Load your Random Forest model
model = load("../models/rf.joblib")

# 5) Pull out importances
imp = model.feature_importances_
fi = pd.DataFrame({
    "feature": X_train.columns,
    "importance": imp
}).sort_values("importance", ascending=False)

# 6) Bar chart of top 15
top_n = 15
plt.figure(figsize=(6, 4 + top_n*0.2))
plt.barh(fi["feature"].head(top_n)[::-1], fi["importance"].head(top_n)[::-1])
plt.xlabel("Importance")
plt.title("Top 15 Feature Importances (RF)")
plt.tight_layout()
plt.show()

# 7) Show the table
fi.head(top_n).reset_index(drop=True)
# Out:
#          feature  importance
# 0  minutes_roll3    0.393385
# 1   points_roll3    0.305107
# 2        minutes    0.226034
# 3          goals    0.038986
# 4        assists    0.036487

# %%
import sys, os
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

import sys, os
import pandas as pd
from src.features import load_processed, make_features, get_X_y
from sklearn.model_selection import train_test_split
from joblib import load
import matplotlib.pyplot as plt

# 1) Make sure src/ is importable
ROOT = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
if ROOT not in sys.path:
    sys.path.insert(0, ROOT)

# 2) Load & featurize
df   = load_processed("../data/processed/player_gw_stats.csv")
feat = make_features(df, window=3)
X, y = get_X_y(feat)

# 3) Same train/test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, shuffle=False
)

# 4) Load your model
model = load("../models/rf_tuned.joblib")  # or rf.joblib

# 5) Predict
preds = model.predict(X_test)

# 6a) Zoomed scatter
plt.figure(figsize=(6,6))
plt.scatter(y_test, preds, alpha=0.3)
limit = 20
plt.plot([0,limit],[0,limit],"--", linewidth=1)
plt.xlim(0, limit)
plt.ylim(0, limit)
plt.xlabel("Actual FPL Points")
plt.ylabel("Predicted FPL Points")
plt.title("Zoomed: Pred vs Actual (0–20)")
plt.show()

# 6b) Hexbin density
plt.figure(figsize=(6,6))
hb = plt.hexbin(y_test, preds, gridsize=40)  # no cmap → default colormap
plt.plot([0,limit],[0,limit],"--", linewidth=1)
plt.xlim(0, limit)
plt.ylim(0, limit)
plt.xlabel("Actual FPL Points")
plt.ylabel("Predicted FPL Points")
plt.title("Density (Hexbin) Pred vs Actual (0–20)")
plt.colorbar(label="Count")
plt.show()
